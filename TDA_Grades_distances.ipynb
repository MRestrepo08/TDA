# %%
#pip install --upgrade numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import matplotlib.gridspec as gridspec
#import networkx as nx
#import IPython.display as Video

# %%
import ripser
import persim

# %%
# %matplotlib inline

# %%
asignaturas2 = {'ALGEBRA LINEAL' : 1,
'BIOMATEMATICAS I' : 1,
'BIOMATEMATICAS II' : 1,
'CALCULO DIFERENCIAL' : 2,
'CALCULO DIFERENCIAL E INTEGRAL' : 2,
'CALCULO INTEGRAL' : 2,
'CALCULO VECTORIAL' : 2,
'DIFERENTIAL CALCULUS' : 2,
'ECUACIONES DIFERENCIALES' : 2,
'ESTADÍSTICA' : 3,
'ESTADÍSTICA DESCRIPTIVA' : 3,
'ESTADÍSTICA I' : 3,
'ESTADÍSTICA II' : 3,
'ESTADÍSTICA III' : 3,
'ESTADÍSTICA INFERENCIAL' : 3,
'INVESTIGACION DE OPERACIONES' : 4,
'LÓGICA Y RAZONAMIENTO MATEMÁTICO' : 1,
'MATEMATICAS AVANZADAS' : 4,
'MATEMATICAS BASICAS' : 5,
'MATEMATICAS ESPECIALES' : 4,
'MATEMÁTICAS I' : 1,
'MATEMÁTICAS II' : 1,
'MATEMÁTICAS III' : 2,
'METODOS MATEMATICOS' : 4,
'MÉTODOS NUMÉRICOS' : 4,
'MODELOS MATEMATICOS DE ADMON.' : 1,
'PROBABILIDAD Y ESTADISTICA' : 3,
'SISTEMAS LINEALES': 1}

# %%
from persim import plot_diagrams

# %%
#import teaspoon.MakeData.PointCloud as makePtCloud
#import teaspoon.TDA.Draw as Draw

# %%
df1 = pd.read_excel('19_1_1.xlsx', sheet_name='Hoja_1')
df2 = pd.read_excel('19_1_2.xlsx', sheet_name='Hoja_1')
df3 = pd.read_excel('19_1_3.xlsx', sheet_name='Hoja_1')
df4 = pd.read_excel('19_2_1.xlsx', sheet_name='Hoja_1')
df5 = pd.read_excel('19_2_2.xlsx', sheet_name='Hoja_1')
df6 = pd.read_excel('19_2_3.xlsx', sheet_name='Hoja_1')
df7 = pd.read_excel('20_1_1.xlsx', sheet_name='Hoja_1')
df8 = pd.read_excel('20_1_2.xlsx', sheet_name='Hoja_1')
df9 = pd.read_excel('20_1_3.xlsx', sheet_name='Hoja_1')
df10 = pd.read_excel('20_2_1.xlsx', sheet_name='Hoja_1')
df11 = pd.read_excel('20_2_2.xlsx', sheet_name='Hoja_1')
df12 = pd.read_excel('20_2_3.xlsx', sheet_name='Hoja_1')
df13 = pd.read_excel('21_1_1.xlsx', sheet_name='Hoja_1')
df14 = pd.read_excel('21_1_2.xlsx', sheet_name='Hoja_1')
df15 = pd.read_excel('21_1_3.xlsx', sheet_name='Hoja_1')
df16 = pd.read_excel('21_2_1.xlsx', sheet_name='Hoja_1')
df17 = pd.read_excel('21_2_2.xlsx', sheet_name='Hoja_1')
df18 = pd.read_excel('21_2_3.xlsx', sheet_name='Hoja_1')
df19 = pd.read_excel('22_1_1.xlsx', sheet_name='Hoja_1')
df20 = pd.read_excel('22_1_2.xlsx', sheet_name='Hoja_1')
df21 = pd.read_excel('22_1_3.xlsx', sheet_name='Hoja_1')
df22 = pd.read_excel('22_2_1.xlsx', sheet_name='Hoja_1')
df23 = pd.read_excel('22_2_2.xlsx', sheet_name='Hoja_1')
df24 = pd.read_excel('22_2_3.xlsx', sheet_name='Hoja_1')

# %%
#df0['NOMBRE_ASIGNATURA'] = df0['NOMBRE_ASIGNATURA'].map(asignaturas2)
df1['NOMBRE_ASIGNATURA'] = df1['NOMBRE_ASIGNATURA'].map(asignaturas2)
df2['NOMBRE_ASIGNATURA'] = df2['NOMBRE_ASIGNATURA'].map(asignaturas2)
df3['NOMBRE_ASIGNATURA'] = df3['NOMBRE_ASIGNATURA'].map(asignaturas2)
df4['NOMBRE_ASIGNATURA'] = df4['NOMBRE_ASIGNATURA'].map(asignaturas2)
df5['NOMBRE_ASIGNATURA'] = df5['NOMBRE_ASIGNATURA'].map(asignaturas2)
df6['NOMBRE_ASIGNATURA'] = df6['NOMBRE_ASIGNATURA'].map(asignaturas2)
df7['NOMBRE_ASIGNATURA'] = df7['NOMBRE_ASIGNATURA'].map(asignaturas2)
df8['NOMBRE_ASIGNATURA'] = df8['NOMBRE_ASIGNATURA'].map(asignaturas2)
df9['NOMBRE_ASIGNATURA'] = df9['NOMBRE_ASIGNATURA'].map(asignaturas2)
df10['NOMBRE_ASIGNATURA'] = df10['NOMBRE_ASIGNATURA'].map(asignaturas2)
df11['NOMBRE_ASIGNATURA'] = df11['NOMBRE_ASIGNATURA'].map(asignaturas2)
df12['NOMBRE_ASIGNATURA'] = df12['NOMBRE_ASIGNATURA'].map(asignaturas2)
df13['NOMBRE_ASIGNATURA'] = df13['NOMBRE_ASIGNATURA'].map(asignaturas2)
df14['NOMBRE_ASIGNATURA'] = df14['NOMBRE_ASIGNATURA'].map(asignaturas2)
df15['NOMBRE_ASIGNATURA'] = df15['NOMBRE_ASIGNATURA'].map(asignaturas2)
df16['NOMBRE_ASIGNATURA'] = df16['NOMBRE_ASIGNATURA'].map(asignaturas2)
df17['NOMBRE_ASIGNATURA'] = df17['NOMBRE_ASIGNATURA'].map(asignaturas2)
df18['NOMBRE_ASIGNATURA'] = df18['NOMBRE_ASIGNATURA'].map(asignaturas2)
df19['NOMBRE_ASIGNATURA'] = df19['NOMBRE_ASIGNATURA'].map(asignaturas2)
df20['NOMBRE_ASIGNATURA'] = df20['NOMBRE_ASIGNATURA'].map(asignaturas2)
df21['NOMBRE_ASIGNATURA'] = df21['NOMBRE_ASIGNATURA'].map(asignaturas2)
df22['NOMBRE_ASIGNATURA'] = df22['NOMBRE_ASIGNATURA'].map(asignaturas2)
df23['NOMBRE_ASIGNATURA'] = df23['NOMBRE_ASIGNATURA'].map(asignaturas2)
df24['NOMBRE_ASIGNATURA'] = df24['NOMBRE_ASIGNATURA'].map(asignaturas2)

# %%
data1 = df1[(df1['CONTRATO'] == 2) & (df1['ESTAAPROCALI'] == 0)]
data2 = df2[(df2['CONTRATO'] == 2) & (df2['ESTAAPROCALI'] == 0)]
data3 = df3[(df3['CONTRATO'] == 2) & (df3['ESTAAPROCALI'] == 0)]
data4 = df4[(df4['CONTRATO'] == 2) & (df4['ESTAAPROCALI'] == 0)]
data5 = df5[(df5['CONTRATO'] == 2) & (df5['ESTAAPROCALI'] == 0)]
data6 = df6[(df6['CONTRATO'] == 2) & (df6['ESTAAPROCALI'] == 0)]
data7 = df7[(df7['CONTRATO'] == 2) & (df7['ESTAAPROCALI'] == 0)]
data8 = df8[(df8['CONTRATO'] == 2) & (df8['ESTAAPROCALI'] == 0)]
data9 = df9[(df9['CONTRATO'] == 2) & (df9['ESTAAPROCALI'] == 0)]
data10 = df10[(df10['CONTRATO'] == 2) & (df10['ESTAAPROCALI'] == 0)]
data11 = df11[(df11['CONTRATO'] == 2) & (df11['ESTAAPROCALI'] == 0)]
data12 = df12[(df12['CONTRATO'] == 2) & (df12['ESTAAPROCALI'] == 0)]
data13 = df13[(df13['CONTRATO'] == 2) & (df13['ESTAAPROCALI'] == 0)]
data14 = df14[(df14['CONTRATO'] == 2) & (df14['ESTAAPROCALI'] == 0)]
data15 = df15[(df15['CONTRATO'] == 2) & (df15['ESTAAPROCALI'] == 0)]
data16 = df16[(df16['CONTRATO'] == 2) & (df16['ESTAAPROCALI'] == 0)]
data17 = df17[(df17['CONTRATO'] == 2) & (df17['ESTAAPROCALI'] == 0)]
data18 = df18[(df18['CONTRATO'] == 2) & (df18['ESTAAPROCALI'] == 0)]
data19 = df19[(df19['CONTRATO'] == 2) & (df19['ESTAAPROCALI'] == 0)]
data20 = df20[(df20['CONTRATO'] == 2) & (df20['ESTAAPROCALI'] == 0)]
data21 = df21[(df21['CONTRATO'] == 2) & (df21['ESTAAPROCALI'] == 0)]
data22 = df22[(df22['CONTRATO'] == 2) & (df22['ESTAAPROCALI'] == 0)]
data23 = df23[(df23['CONTRATO'] == 2) & (df23['ESTAAPROCALI'] == 0)]
data24 = df24[(df24['CONTRATO'] == 2) & (df24['ESTAAPROCALI'] == 0)]

# %%
features = [c for c in df1.columns if c not in ['Unnamed: 0','NOMBRE_PROFESOR','NOMBRE_ASIGNATURA']]

# %%
X1 = np.array(data1[features].fillna(0))
X2 = np.array(data2[features].fillna(0))
X3 = np.array(data3[features].fillna(0))
X4 = np.array(data4[features].fillna(0))
X5 = np.array(data5[features].fillna(0))
X6 = np.array(data6[features].fillna(0))
X7 = np.array(data7[features].fillna(0))
X8 = np.array(data8[features].fillna(0))
X9 = np.array(data9[features].fillna(0))
X10 = np.array(data10[features].fillna(0))
X11 = np.array(data11[features].fillna(0))
X12 = np.array(data12[features].fillna(0))
X13 = np.array(data13[features].fillna(0))
X14 = np.array(data14[features].fillna(0))
X15 = np.array(data15[features].fillna(0))
X16 = np.array(data16[features].fillna(0))
X17 = np.array(data17[features].fillna(0))
X18 = np.array(data18[features].fillna(0))
X19 = np.array(data19[features].fillna(0))
X20 = np.array(data20[features].fillna(0))
X21 = np.array(data21[features].fillna(0))
X22 = np.array(data22[features].fillna(0))
X23 = np.array(data23[features].fillna(0))
X24 = np.array(data24[features].fillna(0))

# %%
#diagrams0 = ripser.ripser(X0)['dgms']
#plot_diagrams(diagrams0, show=True)

# %%
diagrams1 = ripser.ripser(X1)['dgms']
diagrams2 = ripser.ripser(X2)['dgms']
diagrams3 = ripser.ripser(X3)['dgms']
diagrams4 = ripser.ripser(X4)['dgms']
diagrams5 = ripser.ripser(X5)['dgms']
diagrams6 = ripser.ripser(X6)['dgms']
diagrams7 = ripser.ripser(X7)['dgms']
diagrams8 = ripser.ripser(X8)['dgms']
diagrams9 = ripser.ripser(X9)['dgms']
diagrams10 = ripser.ripser(X10)['dgms']
diagrams11 = ripser.ripser(X11)['dgms']
diagrams12 = ripser.ripser(X12)['dgms']
diagrams13 = ripser.ripser(X13)['dgms']
diagrams14 = ripser.ripser(X14)['dgms']
diagrams15 = ripser.ripser(X15)['dgms']
diagrams16 = ripser.ripser(X16)['dgms']
diagrams17 = ripser.ripser(X17)['dgms']
diagrams18 = ripser.ripser(X18)['dgms']
diagrams19 = ripser.ripser(X19)['dgms']
diagrams20 = ripser.ripser(X20)['dgms']
diagrams21 = ripser.ripser(X21)['dgms']
diagrams22 = ripser.ripser(X22)['dgms']
diagrams23 = ripser.ripser(X23)['dgms']
diagrams24 = ripser.ripser(X24)['dgms']

# %%
list = [diagrams1[0],diagrams2[0],diagrams3[0],diagrams4[0],diagrams5[0],diagrams6[0],diagrams7[0],diagrams8[0],diagrams9[0],diagrams10[0],diagrams11[0],diagrams12[0],diagrams13[0],diagrams14[0],diagrams15[0],diagrams16[0],diagrams17[0],diagrams18[0],diagrams19[0],diagrams20[0],diagrams21[0],diagrams22[0],diagrams23[0],diagrams24[0]]
distancias = []
for _ in list:
    dist, matching = persim.bottleneck(diagrams1[0], _, matching=True)
    distancias.append(dist)
print(distancias)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/persim/bottleneck.py:56: UserWarning: dgm1 has points with non-finite death times;ignoring those points
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/persim/bottleneck.py:66: UserWarning: dgm2 has points with non-finite death times;ignoring those points
#   warnings.warn(
# [0.0, 32.02714538574219, 32.00250244140625, 44.063812255859375, 46.713401794433594, 41.058815002441406, 30.950233459472656, 30.939102172851562, 80.38981628417969, 35.10626983642578, 40.019264221191406, 49.052940368652344, 49.052940368652344, 25.159942626953125, 31.887657165527344, 40.92890167236328, 40.51531982421875, 29.255943298339844, 34.05914306640625, 26.017200469970703, 20.087432861328125, 50.50495147705078, 30.045799255371094, 29.242523193359375]

